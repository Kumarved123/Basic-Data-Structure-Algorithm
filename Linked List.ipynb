# %%
#simple singly linked list
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None



class Linked_list:
    def __init__(self):
        self.head = None
        
    def printlist(self):
        printval = self.head
        while printval is not None:
            print (printval.data)
            printval = printval.next
        

list = Linked_list()
list.head = Node(1)
n2 = Node(2)
n3 = Node(3)
n4 = Node(4)

list.head.next = n2;
n2.next = n3
n3.next = n4


list.printlist()
# Out:
# 1
# 2
# 3
# 4

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        
    
class Linkedlist:
    def __init__(self):
        self.head = None
        
        
    def printlist(self):
        Print = self.head
        while Print is not None:
            print(Print.data)
            Print = Print.next
            
    def add_data(self, New_data):
        new_node = Node(New_data)
        new_node.head = self.head
        self.head = new_node
            
            
list1 = Linkedlist()
list1.head = Node('ved Ji')
n2 = Node('Rahul Ji')
n3 = Node('Dev Ji')
n4 = Node('Sweety Ji')
n5 = Node('Brother Ji')
n6 = Node('Sister Ji')

list1.head.next = n2
n2.next = n3
n3.next = n4
n4.next = n5
n5.next = n6

list1.printlist()
# Out:
# ved Ji
# Rahul Ji
# Dev Ji
# Sweety Ji
# Brother Ji
# Sister Ji

# %%
#isertig new element between the liked list
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        
class Linked_list:
    def __init__(self):
        self.head = None 

        
    def printlist(self):
        Print = self.head
        while Print is not None:
            print(Print.data)
            Print = Print.next
            
    def insertion_start(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node
        
        
    def insertion_between(self, prev_node, data):
        if prev_node is None:
            print("The given previous node must inLinkedList.")
            return 
        new_node = Node(data)
        new_node.next = prev_node.next
        prev_node.next = new_node
        
    def insertion_last(self, data):
        new_node = Node(data)
        if self.head is None: 
            self.head = new_node 
            return
        last = self.head 
        while (last.next): 
            last = last.next
        last.next =  new_node
        
list1 = Linked_list()
list1.head = Node('ved Ji')
n2 = Node('Rahul Ji')
n3 = Node('Dev Ji')
n4 = Node('Sweety Ji')
n5 = Node('Brother Ji')
n6 = Node('Sister Ji')

list1.head.next = n2
n2.next = n3
n3.next = n4
n4.next = n5
n5.next = n6        
        
        


list1.insertion_start('Ved praksh')      
list1.insertion_between(n3,'Ved praksa')
list1.insertion_last('Ved praksh')
list1.printlist()
# Out:
# Ved praksh
# ved Ji
# Rahul Ji
# Dev Ji
# Ved praksa
# Sweety Ji
# Brother Ji
# Sister Ji
# Ved praksh

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None



class Linked_list:
    def __init__(self):
        self.head = None
        
    def printlist(self):
        printval = self.head
        while printval is not None:
            print (printval.data)
            printval = printval.next
            
    def delete(self, node):
        temp = self.head
        if (temp is not None):
            if temp.data == node :
                self.head = temp.data
                temp = None
                return
            
        while(temp is not None):
            
        if(temp == None): 

list = Linked_list()
list.head = Node(1)
n2 = Node(2)
n3 = Node(3)
n4 = Node(4)

list.head.next = n2;
n2.next = n3
n3.next = n4


list.printlist()

# %%
#delete a element in a linked list
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        
class Linked_list :
    def __init__(self):
        self.head = None
        
    def printlist(self):
        Print = self.head
        while Print is not None:
            print(Print.data)
            Print = Print.next
            
    def delete(self, key):
        temp = self.head
        
        if (temp.data == key):
            self.head == temp.next
            temp = None
            return
            
        while temp is not None:
            if (temp.data == key):
                break
                
            prev = temp
            temp = temp.next
            
        if (temp == None):
            return
        prev.next = temp.next
        temp = None
    def count(self):
        count = 0
        temp = self.head
        while temp is not None:
            count = count + 1
            temp = temp.next
        return count
    def sorting(self):
        temp_list = []
        temp = self.head
        while temp is not None:
            temp_list.append(temp.data)
            temp = temp.next
        return temp_list
    def sort(self, List):
        list.sort()
        return List
        
            
        
            
            
list1 = Linked_list()
list1.head = Node(17)
n2 = Node(9)
n3 = Node(7)
n4 = Node(5)
n5 = Node(-1)
n6 = Node(14)

list1.head.next = n2
n2.next = n3
n3.next = n4
n4.next = n5
n5.next = n6 

list1.printlist()

list1.count()
# Out:
# 17
# 9
# 7
# 5
# -1
# 14
# 6

# %%
#delete a element in a linked list
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        
class Linked_list :
    def __init__(self):
        self.head = None
        
    def printlist(self):
        Print = self.head
        while Print is not None:
            print(Print.data)
            Print = Print.next
            
    def delete(self, key):
        temp = self.head
        
        if (temp.data == key):
            self.head == temp.next
            temp = None
            return
            
        while temp is not None:
            if (temp.data == key):
                break
                
            prev = temp
            temp = temp.next
            
        if (temp == None):
            return
        prev.next = temp.next
        temp = None
        
    def delete_pos(self, position):
        temp = self.head
        if position = 0:
            self.head = self.next
            temp = None
            return
        
        for i in range(position - 1):
            temp = temp.next
            if temp is None: 
                break
            
            
            
            
list1 = Linked_list()
list1.head = Node('ved Ji')
n2 = Node('Rahul Ji')
n3 = Node('Dev Ji')
n4 = Node('Sweety Ji')
n5 = Node('Brother Ji')
n6 = Node('Sister Ji')

list1.head.next = n2
n2.next = n3
n3.next = n4
n4.next = n5
n5.next = n6 

list1.printlist()
list1.delete('Rahul Ji')
list1.printlist()
